# %%
#TEAM 1 
#GNANESH.A       -   PES2UG20CS122
#B V MURALI SAI  -   PES2UG20CS083
#DEEPAK KUMAR    -   PES2UG20CS104

# %% [markdown]
# <span style="font-size:30px;"> Importing the librarys  </span>

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %% [markdown]
# <span style="font-size:30px;"> Loading the dataset to a pandas datafram</span>

# %%
card_data = pd.read_csv('../input/creditcardfraud/creditcard.csv')

# %% [markdown]
# <span style="font-size:30px;"> First 5 row of the dataset </span>

# %%
card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# <span style="font-size:30px;"> Last 5 row of the dataset </span>

# %%
card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# <span style="font-size:30px;">   Dataset information </span>

# %%
card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# <span style="font-size:30px;">   Checking the number of missing values in each column </span>

# %%
card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# <span style="font-size:30px;">   Distribution of legit transactions & fraudulent transactions </span>

# %%
card_data['Class'].value_counts()  # the dataset is highly unbalanced , where 0 --> Normal Transaction and 1--> fradulent transaction
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# <span style="font-size:30px;">   Separating the data for analysis  </span>

# %%
legit = card_data[card_data.Class == 0]
fraud = card_data[card_data.Class == 1]

# %% [markdown]
# <span style="font-size:30px;">   Statistical measures of the data  </span>

# %%
#for legit transaction 
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#for fraud transaction
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# <span style="font-size:30px;">   UNDERSAMPLING </span>

# %%
#Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#Number of Fraudulent Transactions --> 492
legit_sample = legit.sample(n=492) # it will randobly select 492 rows in not frard

# %% [markdown]
# <span style="font-size:30px;">   Concatenating two DataFrames </span>

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0) # we want to add row wise of axis=0
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 43522    41541.0  1.017597 -0.614946  1.091626 -0.017019 -0.865996  0.801200
# 34273    37591.0  0.946040 -0.437897  0.724807  0.067316 -0.775668 -0.199892
# 79939    58253.0  0.966628 -0.391247  1.249696  0.729188 -0.470212  1.540252
# 233169  147465.0  1.914229  0.497687 -0.869688  3.386267  1.021489  1.056712
# 59018    48652.0 -0.561216 -3.018429 -1.174788  0.768474 -1.118039 -0.565268
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 43522  -0.923912  0.475695  0.868162  ...  0.007679  0.153640  0.080567
# 34273  -0.276001  0.091347  0.018288  ... -0.027743 -0.324118  0.092667
# 79939  -0.972278  0.669410  0.938798  ...  0.047155  0.458087  0.200976
# 233169  0.015030  0.114498 -1.210923  ...  0.002516  0.019798  0.107747
# 59018   1.554775 -0.587355  0.051124  ...  0.494298 -0.593678 -1.007685
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %% [markdown]
# <span style="font-size:30px;">   Splitting the data into Features & Targets (undersample)</span>

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']
print("X =  \n"  ,X)
print("\n\n\n\n\n")
print("Y =  \n" ,Y)
# Out:
# X =
#              Time        V1        V2        V3        V4        V5        V6  \
# 43522    41541.0  1.017597 -0.614946  1.091626 -0.017019 -0.865996  0.801200
# 34273    37591.0  0.946040 -0.437897  0.724807  0.067316 -0.775668 -0.199892
# 79939    58253.0  0.966628 -0.391247  1.249696  0.729188 -0.470212  1.540252
# 233169  147465.0  1.914229  0.497687 -0.869688  3.386267  1.021489  1.056712
# 59018    48652.0 -0.561216 -3.018429 -1.174788  0.768474 -1.118039 -0.565268
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# <span style="font-size:30px;"> Split the data into Training data & Testing Data </span>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print("X = " ,X.shape,"X_train = ", X_train.shape, " X_test =" ,X_test.shape)
print("Y = " ,Y.shape,"Y_train = ", Y_train.shape, " Y_test =" ,Y_test.shape)
# Out:
# X =  (984, 30) X_train =  (787, 30)  X_test = (197, 30)
# Y =  (984,) Y_train =  (787,)  Y_test = (197,)

# %% [markdown]
# <span style="font-size:30px;"> Building the Random Forest Classifier (RANDOM FOREST) - UnderSampaling
# </span>

# %%
from sklearn.ensemble import RandomForestClassifier
# random forest model creation
rfc = RandomForestClassifier(n_estimators = 100)
rfc.fit(X_train,Y_train)
# predictions
y_pred_rand_under = rfc.predict(X_test)
print(X_train.shape ,Y_train.shape, y_pred_rand_under.shape,Y_test.shape)
# Out:
# (787, 30) (787,) (197,) (197,)

# %% [markdown]
# <span style="font-size:30px;">  Evaluating the classifier - Random Forest</span>

# %%
#Evaluating the classifier
#printing every score of the classifier
#scoring in any thing
from sklearn.metrics import classification_report, accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,roc_curve,auc
from sklearn.metrics import confusion_matrix,plot_confusion_matrix,classification_report
import seaborn as sns
print("The model used is Random Forest classifier")
acc= accuracy_score(Y_test,y_pred_rand_under)
print("The accuracy is  {}".format(acc))
prec= precision_score(Y_test,y_pred_rand_under)
print("The precision is {}".format(prec))
rec= recall_score(Y_test,y_pred_rand_under)
print("The recall is {}".format(rec))
f1= f1_score(Y_test,y_pred_rand_under)
print("The F1-Score is {}".format(f1))
MCC=matthews_corrcoef(Y_test,y_pred_rand_under)
print("The Matthews correlation coefficient is {}".format(MCC))

fp,tp,thresholds = roc_curve(Y_test,y_pred_rand_under)
roc_auc = auc(fp,tp)
print("The AUC-Score is {}".format(roc_auc))

cnf_matrix = confusion_matrix(Y_test, y_pred_rand_under)

print(cnf_matrix)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')


labels = ['Non-fraud', 'Fraud']
print(classification_report(Y_test, y_pred_rand_under, target_names=labels))
# Out:
# The model used is Random Forest classifier
# The accuracy is  0.9441624365482234
# The precision is 0.9896907216494846
# The recall is 0.9056603773584906
# The F1-Score is 0.9458128078817735
# The Matthews correlation coefficient is 0.8921775684158355
# The AUC-Score is 0.9473356831847398
# [[90  1]
#  [10 96]]
#               precision    recall  f1-score   support
#
#    Non-fraud       0.90      0.99      0.94        91
#        Fraud       0.99      0.91      0.95       106
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.95      0.94       197
# weighted avg       0.95      0.94      0.94       197

# %%
n_estimators = [1,2,4,8,16,32,64,100,200]
train_results = []
test_results = []

for estimator in n_estimators:
    
    rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
    rf.fit(X_train, Y_train)
    train_pred = rf.predict(X_train)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Y_train, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    train_results.append(roc_auc)
    y_pred = rf.predict(X_test)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(Y_test, y_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    test_results.append(roc_auc)

from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot(n_estimators, train_results, "b", label="Train AUC")
line2, = plt.plot(n_estimators, test_results, "r", label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel("AUC score")
plt.xlabel("n_estimators")
plt.show()

# %% [markdown]
# <span style="font-size:30px;"> Logistic Regression UnderSampling  </span>

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train , Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <span style="font-size:30px;"> Evaluating the classifier - Logistic Regression  </span>

# %%
# accuracy on test data
y_pred_logg_under = model.predict(X_test)
acc= accuracy_score(Y_test,y_pred_logg_under)
print("The accuracy is  {}".format(acc))
prec= precision_score(Y_test,y_pred_logg_under)
print("The precision is {}".format(prec))
rec= recall_score(Y_test,y_pred_logg_under)
print("The recall is {}".format(rec))
f1= f1_score(Y_test,y_pred_logg_under)
print("The F1-Score is {}".format(f1))
MCC=matthews_corrcoef(Y_test,y_pred_logg_under)
print("The Matthews correlation coefficient is {}".format(MCC))

cnf_matrix = confusion_matrix(Y_test, y_pred_logg_under)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

labels = ['Non-fraud', 'Fraud']
print(classification_report(Y_test, y_pred_logg_under, target_names=labels))
# Out:
# The accuracy is  0.9289340101522843
# The precision is 0.9772727272727273
# The recall is 0.8775510204081632
# The F1-Score is 0.9247311827956989
# The Matthews correlation coefficient is 0.8622509784057941
#               precision    recall  f1-score   support
#
#    Non-fraud       0.89      0.98      0.93        99
#        Fraud       0.98      0.88      0.92        98
#
#     accuracy                           0.93       197
#    macro avg       0.93      0.93      0.93       197
# weighted avg       0.93      0.93      0.93       197

# %% [markdown]
# <span style="font-size:30px;"> XGBOOSTPLEASE  - UNDERSAMPLE  </span>

# %%
import xgboost as xgb
model = xgb.XGBClassifier(n_estimators = 5000, max_depth = 30, learning_rate = 0.01)
model.fit(X_train, Y_train)
y_pred_xg_under = model.predict(X_test)

cnf_matrix = confusion_matrix(Y_test, y_pred_xg_under)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(Y_test, y_pred_xg_under))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        91
#            1       0.99      0.91      0.95       106
#
#     accuracy                           0.94       197
#    macro avg       0.94      0.95      0.94       197
# weighted avg       0.95      0.94      0.94       197

# %% [markdown]
# <span style="font-size:40px;"> SMOTE(
#     Over
#     sample)</span>

# %% [markdown]
# <span style="font-size:30px;">   Splitting the data into Features & Targets (Oversample)</span>

# %%
from sklearn.model_selection import train_test_split as holdout
card_data = pd.read_csv('../input/creditcardfraud/creditcard.csv')
x_over = np.array(card_data.iloc[:, card_data.columns != 'Class'])
y_over = np.array(card_data.iloc[:, card_data.columns == 'Class'])
x_train_over, x_test_over, y_train_over, y_test_over = holdout(x_over, y_over, test_size=0.2, random_state=0)
print(y_test_over.shape,x_train_over.shape)
# Out:
# (56962, 1) (227845, 30)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
x_train_s, y_train_s = sm.fit_resample(x_train_over, y_train_over.ravel())

# %% [markdown]
# <span style="font-size:30px;"> Building the Random Forest Classifier (RANDOM FOREST) - OverSampaling
# </span>

# %%
from sklearn.ensemble import RandomForestClassifier
# random forest model creation
rfc1 = RandomForestClassifier() #object of random forest get created 
rfc1.fit(x_train_s, y_train_s) # we a random model on X train and Y train 
# predictions
y_pred_rand_over = rfc1.predict(x_test_over)

# %% [markdown]
# <span style="font-size:30px;">  Evaluating the classifier - Random Forest</span>

# %%
#Evaluating the classifier
#printing every score of the classifier
#scoring in any thing
from sklearn.metrics import classification_report, accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import confusion_matrix,plot_confusion_matrix,classification_report
print("The model used is Random Forest classifier")
acc= accuracy_score(y_test_over,y_pred_rand_over)
print("The accuracy is  {}".format(acc))
prec= precision_score(y_test_over,y_pred_rand_over)
print("The precision is {}".format(prec))
rec= recall_score(y_test_over,y_pred_rand_over)
print("The recall is {}".format(rec))
f1= f1_score(y_test_over,y_pred_rand_over)
print("The F1-Score is {}".format(f1))
MCC=matthews_corrcoef(y_test_over,y_pred_rand_over)
print("The Matthews correlation coefficient is {}".format(MCC))


cnf_matrix = confusion_matrix(y_test_over, y_pred_rand_over)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test_over, y_pred_rand_over))
# Out:
# The model used is Random Forest classifier
# The accuracy is  0.9994908886626171
# The precision is 0.86
# The recall is 0.8514851485148515
# The F1-Score is 0.8557213930348259
# The Matthews correlation coefficient is 0.8554770186222138
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.86      0.85      0.86       101
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.93      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# <span style="font-size:30px;"> Logistic Regression OverSampling  </span>

# %%
model = LogisticRegression()
model.fit(x_train_s, y_train_s)
Y_train_prediction = model.predict(x_test_over)
acc= accuracy_score(y_test_over,Y_train_prediction)
print("The accuracy is  {}".format(acc))
prec= precision_score(y_test_over,Y_train_prediction)
print("The precision is {}".format(prec))
rec= recall_score(y_test_over,Y_train_prediction)
print("The recall is {}".format(rec))
f1= f1_score(y_test_over,Y_train_prediction)
print("The F1-Score is {}".format(f1))
MCC=matthews_corrcoef(y_test_over,Y_train_prediction)
print("The Matthews correlation coefficient is {}".format(MCC))

cnf_matrix = confusion_matrix(y_test_over, Y_train_prediction)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

labels = ['Non-fraud', 'Fraud']
print(classification_report(y_test_over, Y_train_prediction, target_names=labels))
# Out:
# The accuracy is  0.966960429760191
# The precision is 0.04543134252169474
# The recall is 0.8811881188118812
# The F1-Score is 0.08640776699029126
# The Matthews correlation coefficient is 0.1958427306027316
#               precision    recall  f1-score   support
#
#    Non-fraud       1.00      0.97      0.98     56861
#        Fraud       0.05      0.88      0.09       101
#
#     accuracy                           0.97     56962
#    macro avg       0.52      0.92      0.53     56962
# weighted avg       1.00      0.97      0.98     56962

# %% [markdown]
# <span style="font-size:30px;"> XGBOOSTPLEASE  - OVERSAMPLE  </span>

# %%
import xgboost as xgb
model = xgb.XGBClassifier(n_estimators = 1000, max_depth = 30, learning_rate = 0.01)
model.fit(x_train_s, y_train_s)
y_pred_xg_over = model.predict(x_test_over)

cnf_matrix = confusion_matrix(y_test_over, y_pred_xg_over)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test_over, y_pred_xg_over))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.82      0.87      0.85       101
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.94      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
